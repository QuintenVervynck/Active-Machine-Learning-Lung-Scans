# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'
from lib.robot import Robot

# %%
rob = Robot("tf-gpu-check")
# Out:
# ROBOT: TF GPU CHECK
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
rob = Robot("al-learn-acc-graph")
# Out:
# ROBOT: AL LEARN ACC GRAPH
# ROBOT: prep data
# Loading local preprocessed dataset...
# Finished
# X_train shape: (3228, 224, 224, 3)
# X_valid & X_test shape: (404, 224, 224, 3)
# y_train shape: (3228,)
# y_valid & y_test shape: (404,)
# ROBOT: train
# ROBOT: training model 1/5
# Iterations: 2
# Size 50
# Epoch 1/3
# 4/4 [==============================] - 23s 6s/step - loss: 5531.6284 - accuracy: 0.4375 - val_loss: 1.1058 - val_accuracy: 0.4400
# Epoch 2/3
# 4/4 [==============================] - 21s 6s/step - loss: 1.1228 - accuracy: 0.3750 - val_loss: 1.1061 - val_accuracy: 0.2200
# Epoch 3/3
# 4/4 [==============================] - 21s 6s/step - loss: 1.7101 - accuracy: 0.2812 - val_loss: 1.0881 - val_accuracy: 0.4400
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.34
# iteration 1, 18 samples left
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/3
# 7/7 [==============================] - 33s 5s/step - loss: 996.8741 - accuracy: 0.4600 - val_loss: 1.1240 - val_accuracy: 0.2200
# Epoch 2/3
# 7/7 [==============================] - 32s 5s/step - loss: 1.0910 - accuracy: 0.3600 - val_loss: 1.1088 - val_accuracy: 0.2200
# Epoch 3/3
# 7/7 [==============================] - 33s 5s/step - loss: 1.1112 - accuracy: 0.3400 - val_loss: 1.1013 - val_accuracy: 0.2200
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.36
# Used samples: 64
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.36
# ROBOT: training model 2/5
# Iterations: 2
# Size 50
# Epoch 1/3
# 4/4 [==============================] - 25s 6s/step - loss: 2339.3088 - accuracy: 0.3438 - val_loss: 1.0936 - val_accuracy: 0.4400
# Epoch 2/3
# 4/4 [==============================] - 22s 6s/step - loss: 1.1019 - accuracy: 0.5625 - val_loss: 1.5139 - val_accuracy: 0.2200
# Epoch 3/3
# 4/4 [==============================] - 23s 6s/step - loss: 1.2074 - accuracy: 0.3125 - val_loss: 1.1072 - val_accuracy: 0.2200
# 2/2 [==============================] - 7s 2s/step
# Test accuracy: 0.36
# iteration 1, 18 samples left
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/3
# 7/7 [==============================] - 33s 5s/step - loss: 316.0267 - accuracy: 0.3400 - val_loss: 1.0910 - val_accuracy: 0.4400
# Epoch 2/3
# 7/7 [==============================] - 35s 5s/step - loss: 1.1002 - accuracy: 0.3800 - val_loss: 1.0910 - val_accuracy: 0.4400
# Epoch 3/3
# 7/7 [==============================] - 35s 5s/step - loss: 1.0853 - accuracy: 0.3800 - val_loss: 1.0715 - val_accuracy: 0.4400
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.34
# Used samples: 64
# 2/2 [==============================] - 7s 3s/step
# Test accuracy: 0.34
# ROBOT: training model 3/5
# Iterations: 2
# Size 50
# Epoch 1/3
# 4/4 [==============================] - 25s 6s/step - loss: 340.5613 - accuracy: 0.3438 - val_loss: 1.0836 - val_accuracy: 0.3400
# Epoch 2/3
# 4/4 [==============================] - 23s 6s/step - loss: 1.1108 - accuracy: 0.3125 - val_loss: 1.1313 - val_accuracy: 0.2200
# Epoch 3/3
# 4/4 [==============================] - 22s 6s/step - loss: 1.1131 - accuracy: 0.4062 - val_loss: 1.1072 - val_accuracy: 0.2200
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.36
# iteration 1, 18 samples left
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/3
# 7/7 [==============================] - 33s 5s/step - loss: 829.2056 - accuracy: 0.3200 - val_loss: 1.1072 - val_accuracy: 0.4400
# Epoch 2/3
# 7/7 [==============================] - 31s 5s/step - loss: 1.0926 - accuracy: 0.3800 - val_loss: 1.0803 - val_accuracy: 0.4400
# Epoch 3/3
# 7/7 [==============================] - 33s 5s/step - loss: 1.1005 - accuracy: 0.4000 - val_loss: 1.0741 - val_accuracy: 0.4400
# 2/2 [==============================] - 7s 2s/step
# Test accuracy: 0.34
# Used samples: 64
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.34
# ROBOT: training model 4/5
# Iterations: 2
# Size 50
# Epoch 1/3
# 4/4 [==============================] - 42s 10s/step - loss: 255.1185 - accuracy: 0.5312 - val_loss: 1.0709 - val_accuracy: 0.4400
# Epoch 2/3
# 4/4 [==============================] - 24s 7s/step - loss: 1.1207 - accuracy: 0.3750 - val_loss: 1.1044 - val_accuracy: 0.2200
# Epoch 3/3
# 4/4 [==============================] - 24s 7s/step - loss: 1.2094 - accuracy: 0.3750 - val_loss: 1.1359 - val_accuracy: 0.2200
# 2/2 [==============================] - 7s 2s/step
# Test accuracy: 0.36
# iteration 1, 18 samples left
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/3
# 7/7 [==============================] - 36s 5s/step - loss: 4226.3188 - accuracy: 0.2800 - val_loss: 3.3937 - val_accuracy: 0.2200
# Epoch 2/3
# 7/7 [==============================] - 35s 5s/step - loss: 1.3955 - accuracy: 0.2800 - val_loss: 1.0958 - val_accuracy: 0.4600
# Epoch 3/3
# 7/7 [==============================] - 34s 5s/step - loss: 1.1201 - accuracy: 0.2200 - val_loss: 1.0990 - val_accuracy: 0.2200
# 2/2 [==============================] - 7s 2s/step
# Test accuracy: 0.36
# Used samples: 64
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.36
# ROBOT: training model 5/5
# Iterations: 2
# Size 50
# Epoch 1/3
# 4/4 [==============================] - 24s 6s/step - loss: 573.4139 - accuracy: 0.2500 - val_loss: 1.1698 - val_accuracy: 0.2200
# Epoch 2/3
# 4/4 [==============================] - 23s 6s/step - loss: 1.3300 - accuracy: 0.5000 - val_loss: 1.0928 - val_accuracy: 0.4400
# Epoch 3/3
# 4/4 [==============================] - 26s 7s/step - loss: 1.1013 - accuracy: 0.3438 - val_loss: 1.0911 - val_accuracy: 0.4400
# 2/2 [==============================] - 7s 2s/step
# Test accuracy: 0.34
# iteration 1, 18 samples left
# 1/1 [==============================] - 2s 2s/step
# Epoch 1/3
# 7/7 [==============================] - 35s 5s/step - loss: 3759.0981 - accuracy: 0.3800 - val_loss: 1.1209 - val_accuracy: 0.4400
# Epoch 2/3
# 7/7 [==============================] - 31s 5s/step - loss: 2.1657 - accuracy: 0.5000 - val_loss: 1.1030 - val_accuracy: 0.2200
# Epoch 3/3
# 7/7 [==============================] - 34s 5s/step - loss: 1.0976 - accuracy: 0.3600 - val_loss: 1.1045 - val_accuracy: 0.2200
# 2/2 [==============================] - 7s 2s/step
# Test accuracy: 0.36
# Used samples: 64
# 2/2 [==============================] - 6s 2s/step
# Test accuracy: 0.36

# %%
print(rob.accs)
# Out:
# [0.36, 0.34, 0.34, 0.36, 0.36]

# %%
print(rob.used)
# Out:
# [[16, 22, 12], [16, 22, 12], [16, 22, 12], [16, 22, 12], [16, 22, 12]]

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2022, 11, 28, 9, 20, 34, 373785)

# %%
from math import ceil
ceil(14/32)
# Out:
# 1

# %%
import tensorflow as tf
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1
